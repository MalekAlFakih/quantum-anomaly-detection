# %% [markdown]
# # Quantum Anomaly Detection - Demo Notebook
#
# This notebook demonstrates how to use the `QuantumAnomalyDetector` class.

# %%
# !pip install -q numpy qiskit matplotlib

# %%
import numpy as np
from quantum_anomaly_detection import QuantumAnomalyDetector

# %% [markdown]
# ## Create Sample Data

# %%
X_train = np.random.rand(10, 2)
X_test = np.random.rand(5, 2)

# %% [markdown]
# ## Train and Predict

# %%
detector = QuantumAnomalyDetector(threshold=0.5)
detector.fit(X_train)
scores = detector.predict(X_test)

print("Anomaly scores:", scores)
print("Is sample 0 anomalous?", detector.is_anomalous(scores[0]))
